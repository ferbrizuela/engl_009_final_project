# %%
import pandas as pd
import os
import re
import json
import requests
import random
from bs4 import BeautifulSoup
import lyricsgenius
from collections import Counter
import matplotlib.pyplot as plt

from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import WordPunctTokenizer

# %% [markdown]
# # Context Analysis Era 3

# %%
# %run functions.ipynb
# %run analysis_era_3.ipynb
# Out:
# Top 50 types in Era 3 corpus
# ==================================
# [('you', 393), ('the', 346), ('i', 343), ('and', 215), ('my', 176), ('to', 170), ('in', 155), ('your', 141), ('a', 139), ('it', 134), ('me', 133), ('of', 97), ('know', 95), ('but', 87), ('that', 82), ('for', 79), ('like', 78), ("i'm", 74), ('was', 71), ('all', 63), ('on', 60), ('is', 59), ('when', 58), ('be', 54), ('if', 53), ('never', 50), ('just', 48), ('what', 47), ('time', 46), ('with', 45), ("it's", 44), ('now', 42), ('at', 40), ('so', 39), ("don't", 37), ('up', 37), ('one', 36), ('out', 36), ('they', 32), ("you're", 31), ('this', 31), ('could', 31), ('would', 30), ('love', 29), ("didn't", 28), ('were', 26), ('thing', 26), ('there', 26), ('think', 25), ('down', 25)]
#
#
# Top 50 types in Era 3 songs (num of songs type occurs in)
# ===================================================
# [('in', 27), ('the', 27), ('i', 27), ('but', 26), ('and', 26), ('you', 26), ('of', 25), ('me', 25), ('your', 25), ('to', 24), ('my', 24), ('a', 24), ('it', 22), ('on', 22), ('that', 22), ('know', 21), ('all', 21), ('for', 21), ('just', 20), ('now', 19), ('like', 19), ('be', 18), ('with', 17), ('this', 17), ('when', 17), ('was', 17), ('so', 17), ('one', 16), ('time', 16), ("it's", 16), ('out', 16), ("i'm", 15), ('up', 15), ('at', 15), ('is', 15), ('what', 15), ('down', 14), ('if', 13), ('would', 13), ('from', 13), ('never', 12), ("don't", 12), ('they', 12), ('we', 11), ("you're", 11), ('think', 11), ('only', 11), ('were', 10), ('have', 10), ('had', 10)]
# Stop contains 180 words, such as:
#
#  ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]
# Top 50 types in Era 3 lyrics
# ==================================
# [('know', 95), ('like', 78), ("i'm", 74), ('never', 50), ('time', 46), ('one', 36), ('could', 31), ('would', 30), ('love', 29), ('thing', 26), ('think', 25), ('still', 22), ("'cause", 20), ('go', 20), ('got', 19), ('knew', 18), ('back', 18), ('tell', 18), ('around', 17), ("i'd", 17), ('see', 17), ('call', 17), ('hand', 16), ('come', 16), ("can't", 16), ('watch', 16), ('right', 16), ('take', 15), ('better', 15), ('said', 15), ('dead', 15), ("that's", 15), ('man', 15), ('mine', 14), ('stay', 14), ("would've", 13), ('ooh', 13), ('ever', 13), ('say', 13), ('mad', 13), ('give', 13), ('died', 13), ('sometimes', 13), ('good', 12), ('showed', 12), ('house', 12), ('me?', 12), ('want', 12), ("i've", 12), ('always', 12)]
#
#
# Top 50 types in Era 3 songs (num of songs type occurs in)
# ===================================================
# [('know', 21), ('like', 19), ('one', 16), ('time', 16), ("i'm", 15), ('would', 13), ('never', 12), ('think', 11), ("i'd", 9), ('back', 9), ('heart', 9), ('see', 9), ('could', 9), ('around', 8), ('come', 8), ('said', 8), ("'cause", 8), ('long', 8), ('friends', 8), ('still', 8), ("can't", 8), ('go', 8), ('tell', 8), ('love', 8), ("i've", 8), ('got', 8), ('always', 8), ('good', 7), ('thing', 7), ('make', 7), ('face', 7), ('eyes', 7), ('right', 7), ('life', 7), ('showed', 6), ('made', 6), ('night', 6), ('home', 6), ('new', 6), ('everything', 6), ('hand', 6), ('say', 6), ('want', 6), ("i'll", 6), ('show', 6), ('every', 6), ('pulled', 6), ('wanted', 5), ('shit', 5), ("would've", 5)]
# target word word freq  song freq
# ==============================
# you        393        26
# i          343        27
# me         133        25
# love       29         8
# baby       3          3
# break      3          3
# lover      0          0
# kiss       5          2
# truck      2          1
# mama       0          0
# heart      11         9
# friends    9          8
# friend     4          2
# new        8          6
# home       8          6
# bad        3          3
# can't      16         8
# alone      3          1
# know       95         21
# 0.4141202438943477
# [320, 354, 335, 314, 267, 225, 408, 273, 248, 307, 322, 192, 475, 287, 246, 426, 296, 356, 423, 332, 449, 261, 388, 376, 339, 243, 393]
# 327.962962962963

# %%
kwic_love = []
for song in era_3:
    if song.get('tokens'):
        kwic = make_kwic('love', song['tokens'])
        kwic_love.extend(kwic)
        
print(f'"love" occurs {len(kwic_love)} times in Era 3 lyrics')
love_sorted = sort_kwic(kwic_love, ['L1','R1'])

print_kwic(love_sorted)
# Out:
# "love" occurs 29 times in Era 3 lyrics
#           had nеver seen a  love  as pure as it
#           will never see a  love  as pure as it
#           like it could be  love  i could be the
#           like it could be  love  i could be the
#           here it could be  love  we could be the
#           here it could be  love  we could be the
#       know i'm never gonna  love  again i've got some
#        and i'm never gonna  love  again i'm never gonna
#      again i'm never gonna  love  again i'm never gonna
#      again i'm never gonna  love  again
#           face i still got  love  for you your braids
#           face i still got  love  for you pack your
#        in my highest heels  love  shining just for you
#        in my highest heels  love  shining just for you
#        in my highest heels  love  shining just for you
#        in my highest heels  love  shining just for you
#          somehow i know my  love  should be celebrated but
#          somehow i know my  love  should be celebrated but
#          somehow i know my  love  should be celebrated but
#        like folk songs our  love  lasts so long
#            a folk song our  love  will be passed on
#      braids like a pattern  love  you to the moon
# a speech you're speechless  love  slipped beyond your reaches
#         so much for summer  love  and saying "us" 'cause
#        like folk songs the  love  lasts so long and
#           would be like to  love  you walk past quick
#           would be like to  love  you walk past quick
#       like me never wanted  love  just a fancy car
#          have me? will you  love  me? will you kiss

# %%
kwic_alone = []
for song in era_3:
    if song.get('tokens'):
        kwic = make_kwic('alone', song['tokens'])
        kwic_alone.extend(kwic)
        
print(f'"alone" occurs {len(kwic_alone)} times in your lyrics')

alone_sorted = sort_kwic(kwic_alone, ['L1','R1'])

print_kwic(alone_sorted)
# Out:
# "alone" occurs 3 times in your lyrics
# never leaving well enough  alone  but it would've been
# never leaving well enough  alone  but it would've been
#     another day waking up  alone  but we were something

# %%
kwic_kiss = []
for song in era_3:
    if song.get('tokens'):
        kwic = make_kwic('kiss', song['tokens'])
        kwic_kiss.extend(kwic)
        
print(f'"kiss" occurs {len(kwic_kiss)} times in your lyrics')

kiss_sorted = sort_kwic(kwic_kiss, ['L1','R1'])

print_kwic(kiss_sorted)
# Out:
# "kiss" occurs 5 times in your lyrics
# under my sweatshirt baby  kiss  it better i and
#     linger like a tattoo  kiss  i knew you'd haunt
#     was your favorite to  kiss  in cars and downtown
#        love me? will you  kiss  me on the porch
#   stupid friends? if you  kiss  me will it be

# %%
kwic_baby = []
for song in era_3:
    if song.get('tokens'):
        kwic = make_kwic('baby', song['tokens'])
        kwic_baby.extend(kwic)
        
print(f'"baby" occurs {len(kwic_baby)} times in your lyrics')

baby_sorted = sort_kwic(kwic_baby, ['L1','R1'])

print_kwic(baby_sorted)
# Out:
# "baby" occurs 3 times in your lyrics
#      skies and it's cool  baby  with me and isn't
#   painted by the numbers  baby  but we were making
# hand under my sweatshirt  baby  kiss it better i

# %%
kwic_heart = []
for song in era_3:
    if song.get('tokens'):
        kwic = make_kwic('heart', song['tokens'])
        kwic_heart.extend(kwic)
        
print(f'"heart" occurs {len(kwic_heart)} times in your lyrics')

heart_sorted = sort_kwic(kwic_heart, ['L1','R1'])

print_kwic(heart_sorted)
# Out:
# "heart" occurs 11 times in your lyrics
# i'll keep your brittle  heart  warm if your cascade
# i'll keep your brittle  heart  warm if your cascade
#     been her fault his  heart  gave out and they
#     you have beaten my  heart  don't want no other
#         can aim for my  heart  go for blood but
#      boys who broke my  heart  now i send their
#    here pouring out my  heart  to a stranger but
#    the summer cross my  heart  won’t tell no other
#     i'm fakin' and the  heart  i know i'm breakin'
#    in your wallet your  heart  was glass i dropped
#  the summer cross your  heart  won't tell no other

# %%
kwic_break = []
for song in era_3:
    if song.get('tokens'):
        kwic = make_kwic('break', song['tokens'])
        kwic_break.extend(kwic)
        
print(f'"break" occurs {len(kwic_break)} times in your lyrics')

break_sorted = sort_kwic(kwic_break, ['L1','R1'])

print_kwic(break_sorted)
# Out:
# "break" occurs 3 times in your lyrics
#          you do if i  break  free and leave us
# beautiful and when i  break  it's in a million
#      it is will only  break  their hearts worse that

# %%
kwic_bad = []
for song in era_3:
    if song.get('tokens'):
        kwic = make_kwic('bad', song['tokens'])
        kwic_bad.extend(kwic)
        
print(f'"bad" occurs {len(kwic_bad)} times in your lyrics')

bad_sorted = sort_kwic(kwic_bad, ['L1','R1'])

print_kwic(bad_sorted)
# Out:
# "bad" occurs 3 times in your lyrics
#      madness their men and  bad  habits and then it
#   the holidays linger like  bad  perfume you can run
# you to me? ooh ooh ooh ooh  bad  was the blood of
